# %% [markdown]
# # Housekeep human preferences dataset
#
# In this notebook, we provide a walk through our Housekeep human preferences dataset.
#
# Download the dataset [here](https://drive.google.com/drive/folders/1pnFWwEAtSupY0MCmvfYYaf6-kD9c0dp8) and upload it before running this notebook.

# %% [markdown]
# ## Import packages and compile helper functions

# %%
import numpy as np
import pandas as pd

# %%
def receptacle_labels2vec(x):
  result = np.zeros((128,)) # because of 128 receptacles
  for recep in x:
     result[recep] = 1
  return result


def distance_metric(x, y):

  dot_prod = np.dot(x, y)

  # jaccard distance = 1 - jaccard similarity = 1 - (a n b)/(a U b)
  return 1 - dot_prod/(sum(x**2) + sum(y**2) - dot_prod)

# %% [markdown]
# ## Load dataset

# %%
data_path = './housekeep.npy'
data_dict = np.load(data_path, allow_pickle=True).item()

# %%
objects = data_dict['objects']
rooms = data_dict['rooms']
room_receps = data_dict['room_receptacles']
data = data_dict['data']

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# ### DataFrame
#
# Our data is organized as a pandas DataFrame with following fields:
#
#
#
# **annotator_idx**: The participants are indexed as 0, 1, ..., 370.
#
# **assignment_idx**: The assignments are indexed as 0, 1, ... . Each assignment has a set of 10 tasks which are solved by a single participant. Each individual task involves finding and ranking *correct* and *misplaced* receptacles in a given room for a given object.
#
# We collect 10 annotations for each object-room pair.
#
# **object_idx**: object indexed as 0, 1, ..., 267.
#
# **room_idx**: room indexed as 0, 1, ..., 16.
#
# **correct**/**misplaced**: ranked list of *correct*/*misplaced* room-receptacles. Each room-receptacle is indexed as 0, 1, ..., 127.
#
# **implausible**: list of implausible room-receptacles indexed as 0, 1, ..., 127.

# %%
print(f"Objects ({len(objects)}): {', '.join(objects[:5])}, ...")
print(f"Rooms ({len(rooms)}): {', '.join(rooms[:5])}, ...")
print(f"Room receptacles ({len(room_receps)}): {', '.join(room_receps[:5])}, ...")

# %%
print(f"Total number of rows: {len(data)} (10 x n_objects x n_rooms)")
data.head(5)

# %%
# Let's look at a sample annotation
id = 1

row = data.loc[id]

object_name = objects[row['object_idx']]
room_name = rooms[row['room_idx']]
correct_receps = [room_receps[r].split('|')[1] for r in row['correct']]
misplaced_receps = [room_receps[r].split('|')[1] for r in row['misplaced']]
implausible_receps = [room_receps[r].split('|')[1] for r in row['implausible']]

print(f'Object: {object_name}, Room: {room_name}')
print(f"Correct (ranked): {', '.join(correct_receps)}")
print(f"Incorrect (ranked): {', '.join(misplaced_receps)}")
print(f"Implausible:  {', '.join(implausible_receps)}")

# %% [markdown]
# ## Cluster object-room pairs based on annotator receptacle annotations
#
# Each object = 10 x num_rooms_obj annotations

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
import seaborn as sns

# hyperparameters
CLUSTERS = 4

clustering_pandas_df = pd.DataFrame([], 
    columns=['objectid', 'roomid', 'num_clusters', 'cluster_asgns'])

disagreed_object_names = []

# load objects from file
with open('housekeep_less_than_fair_agreement.txt', 'r') as fh:

  alllines = fh.readlines()
  for line in alllines:
    disagreed_object_names.append(line.split(',')[0])

for object_idx in range(268):
  object_name = objects[object_idx]

  for room_idx in range(17):
    room_name = rooms[room_idx]

    if '{}/{}'.format(object_name, room_name) not in disagreed_object_names:
      continue

    print(f'obj: {object_name}, room: {room_name}') #DEBUG

    filtered_values = np.where(data['object_idx'] == object_idx)
    annotators = []
    datapoints = []

    # lists to vector
    for i, d in data.loc[filtered_values].iterrows():

      vec = np.concatenate([receptacle_labels2vec(d['correct']), 
                              receptacle_labels2vec(d['misplaced']),
                              receptacle_labels2vec(d['implausible'])])

      annotators.append(d['annotator_idx'])
      datapoints.append(vec[np.newaxis, :])

    # array of datapoints
    datapoints_array = np.concatenate(datapoints, axis=0)

    # pairwise distance matrix
    pairwise_dist_mat = np.zeros((len(datapoints_array), len(datapoints_array)))
    for i1, d1 in enumerate(datapoints_array):
      for i2, d2 in enumerate(datapoints_array):
        pairwise_dist_mat[i1, i2] = distance_metric(d1, d2)

    # clusters
    num_clusters = CLUSTERS
    check_flag = False
    no_clustering = False

    while not check_flag:

      if num_clusters == 1:
        no_clustering = True
        break

      clusters = AgglomerativeClustering(n_clusters=num_clusters, affinity="precomputed", linkage="single").fit_predict(pairwise_dist_mat)
      unique_cluster_asgns, cluster_counts = np.unique(clusters, return_counts=True)
      # print(f'for {num_clusters} clusters, cluster asgns: {clusters}') #DEBUG
      check_flag = all([x>=3 for x in cluster_counts])
      num_clusters = num_clusters - 1

    if no_clustering:
      # print(f'{object_name}: no clustering!')
      continue

    clustering_pandas_df = pd.concat([clustering_pandas_df, pd.DataFrame(dict({'object':[object_name],
                                                                                'num_clusters': [num_clusters],
                                                                                'cluster_asgns': (len(clusters)*'{}-').format(*clusters)
                                                                                  }))
                                      ], ignore_index=True)
  
clustering_pandas_df.head(-5)
print('done')
# Out:
# obj: action_figure, room: bathroom
# obj: action_figure, room: bedroom
# obj: action_figure, room: childs_room
# obj: action_figure, room: closet
# obj: action_figure, room: corridor
# obj: action_figure, room: dining_room
# obj: action_figure, room: exercise_room
# obj: action_figure, room: garage
# obj: action_figure, room: home_office
# obj: action_figure, room: kitchen
# obj: action_figure, room: living_room
# obj: action_figure, room: lobby
# obj: action_figure, room: pantry_room
# obj: action_figure, room: playroom
# obj: action_figure, room: storage_room
# obj: action_figure, room: television_room
# obj: action_figure, room: utility_room
# obj: adjustable_wrench, room: bathroom
# obj: adjustable_wrench, room: bedroom
# obj: adjustable_wrench, room: closet
# obj: adjustable_wrench, room: corridor
# obj: adjustable_wrench, room: dining_room
# obj: adjustable_wrench, room: exercise_room
# obj: adjustable_wrench, room: garage
# obj: adjustable_wrench, room: lobby
# obj: adjustable_wrench, room: pantry_room
# obj: android_figure, room: bathroom
# obj: android_figure, room: bedroom
# obj: android_figure, room: childs_room
# obj: android_figure, room: closet
# obj: android_figure, room: corridor
# obj: android_figure, room: dining_room
# obj: android_figure, room: exercise_room
# obj: android_figure, room: garage
# obj: android_figure, room: home_office
# obj: android_figure, room: kitchen
# obj: android_figure, room: living_room
# obj: android_figure, room: lobby
# obj: android_figure, room: pantry_room
# obj: android_figure, room: playroom
# obj: android_figure, room: storage_room
# obj: android_figure, room: television_room
# obj: android_figure, room: utility_room
# obj: anti_slip_tape, room: bathroom
# obj: anti_slip_tape, room: bedroom
# obj: anti_slip_tape, room: childs_room
# obj: anti_slip_tape, room: closet
# obj: anti_slip_tape, room: corridor
# obj: anti_slip_tape, room: dining_room
# obj: anti_slip_tape, room: exercise_room
# obj: anti_slip_tape, room: garage
# obj: anti_slip_tape, room: home_office
# obj: anti_slip_tape, room: kitchen
# obj: anti_slip_tape, room: living_room
# obj: anti_slip_tape, room: lobby
# obj: anti_slip_tape, room: pantry_room
# obj: anti_slip_tape, room: playroom
# obj: anti_slip_tape, room: storage_room
# obj: anti_slip_tape, room: television_room
# obj: antidepressant, room: bathroom
# obj: antidepressant, room: bedroom
# obj: antidepressant, room: childs_room
# obj: antidepressant, room: closet
# obj: antidepressant, room: corridor
# obj: antidepressant, room: dining_room
# obj: antidepressant, room: exercise_room
# obj: antidepressant, room: garage
# obj: antidepressant, room: home_office
# obj: antidepressant, room: kitchen
# obj: antidepressant, room: living_room
# obj: antidepressant, room: lobby
# obj: antidepressant, room: playroom
# obj: antidepressant, room: storage_room
# obj: antidepressant, room: television_room
# obj: antidepressant, room: utility_room
# obj: apple, room: bathroom
# obj: apple, room: bedroom
# obj: apple, room: childs_room
# obj: apple, room: closet
# obj: apple, room: dining_room
# obj: apple, room: exercise_room
# obj: apple, room: garage
# obj: apple, room: home_office
# obj: apple, room: kitchen
# obj: apple, room: living_room
# obj: apple, room: lobby
# obj: apple, room: pantry_room
# obj: apple, room: playroom
# obj: apple, room: storage_room
# obj: apple, room: television_room
# obj: apple, room: utility_room
# obj: backpack, room: bathroom
# obj: backpack, room: bedroom
# obj: backpack, room: closet
# obj: backpack, room: corridor
# obj: backpack, room: dining_room
# obj: backpack, room: exercise_room
# obj: backpack, room: garage
# obj: backpack, room: home_office
# obj: backpack, room: kitchen
# obj: backpack, room: living_room
# obj: backpack, room: lobby
# obj: backpack, room: playroom
# obj: backpack, room: storage_room
# obj: backpack, room: television_room
# obj: backpack, room: utility_room
# obj: balancing_cactus, room: bathroom
# obj: balancing_cactus, room: bedroom
# obj: balancing_cactus, room: childs_room
# obj: balancing_cactus, room: closet
# obj: balancing_cactus, room: corridor
# obj: balancing_cactus, room: dining_room
# obj: balancing_cactus, room: exercise_room
# obj: balancing_cactus, room: garage
# obj: balancing_cactus, room: home_office
# obj: balancing_cactus, room: kitchen
# obj: balancing_cactus, room: living_room
# obj: balancing_cactus, room: lobby
# obj: balancing_cactus, room: pantry_room
# obj: balancing_cactus, room: playroom
# obj: balancing_cactus, room: storage_room
# obj: balancing_cactus, room: television_room
# obj: balancing_cactus, room: utility_room
# obj: banana, room: bathroom
# obj: banana, room: bedroom
# obj: banana, room: childs_room
# obj: banana, room: closet
# obj: banana, room: corridor
# obj: banana, room: dining_room
# obj: banana, room: exercise_room
# obj: banana, room: garage
# obj: banana, room: home_office
# obj: banana, room: kitchen
# obj: banana, room: living_room
# obj: banana, room: lobby
# obj: banana, room: pantry_room
# obj: banana, room: playroom
# obj: banana, room: storage_room
# obj: banana, room: television_room
# obj: banana, room: utility_room
# obj: baseball, room: bathroom
# obj: baseball, room: bedroom
# obj: baseball, room: childs_room
# obj: baseball, room: closet
# obj: baseball, room: exercise_room
# obj: baseball, room: garage
# obj: baseball, room: lobby
# obj: baseball, room: pantry_room
# obj: baseball, room: playroom
# obj: baseball, room: utility_room
# obj: bath_sheet, room: bathroom
# obj: bath_sheet, room: bedroom
# obj: bath_sheet, room: childs_room
# obj: bath_sheet, room: closet
# obj: bath_sheet, room: corridor
# obj: bath_sheet, room: dining_room
# obj: bath_sheet, room: exercise_room
# obj: bath_sheet, room: garage
# obj: bath_sheet, room: home_office
# obj: bath_sheet, room: kitchen
# obj: bath_sheet, room: living_room
# obj: bath_sheet, room: lobby
# obj: bath_sheet, room: playroom
# obj: bath_sheet, room: storage_room
# obj: bath_sheet, room: television_room
# obj: bath_sheet, room: utility_room
# obj: battery, room: closet
# obj: battery, room: corridor
# obj: battery, room: dining_room
# obj: battery, room: exercise_room
# obj: battery, room: garage
# obj: battery, room: home_office
# obj: battery, room: living_room
# obj: battery, room: lobby
# obj: battery, room: playroom
# obj: beard_color_gel, room: bathroom
# obj: beard_color_gel, room: bedroom
# obj: beard_color_gel, room: childs_room
# obj: beard_color_gel, room: closet
# obj: beard_color_gel, room: corridor
# obj: beard_color_gel, room: dining_room
# obj: beard_color_gel, room: exercise_room
# obj: beard_color_gel, room: garage
# obj: beard_color_gel, room: home_office
# obj: beard_color_gel, room: kitchen
# obj: beard_color_gel, room: living_room
# obj: beard_color_gel, room: lobby
# obj: beard_color_gel, room: pantry_room
# obj: beard_color_gel, room: playroom
# obj: beard_color_gel, room: storage_room
# obj: beard_color_gel, room: television_room
# obj: beard_color_gel, room: utility_room
# obj: beauty_pack, room: bathroom
# obj: beauty_pack, room: bedroom
# obj: beauty_pack, room: childs_room
# obj: beauty_pack, room: closet
# obj: beauty_pack, room: corridor
# obj: beauty_pack, room: dining_room
# obj: beauty_pack, room: exercise_room
# obj: beauty_pack, room: garage
# obj: beauty_pack, room: home_office
# obj: beauty_pack, room: kitchen
# obj: beauty_pack, room: living_room
# obj: beauty_pack, room: lobby
# obj: beauty_pack, room: pantry_room
# obj: beauty_pack, room: playroom
# obj: beauty_pack, room: storage_room
# obj: beauty_pack, room: television_room
# obj: beauty_pack, room: utility_room
# obj: bleach_cleanser, room: childs_room
# obj: bleach_cleanser, room: closet
# obj: bleach_cleanser, room: exercise_room
# obj: bleach_cleanser, room: garage
# obj: bleach_cleanser, room: home_office
# obj: bleach_cleanser, room: kitchen
# obj: bleach_cleanser, room: living_room
# obj: bleach_cleanser, room: lobby
# obj: bleach_cleanser, room: pantry_room
# obj: bleach_cleanser, room: playroom
# obj: bleach_cleanser, room: storage_room
# obj: bleach_cleanser, room: television_room
# obj: blender_jar, room: bathroom
# obj: blender_jar, room: bedroom
# obj: blender_jar, room: childs_room
# obj: blender_jar, room: closet
# obj: blender_jar, room: corridor
# obj: blender_jar, room: dining_room
# obj: blender_jar, room: exercise_room
# obj: blender_jar, room: garage
# obj: blender_jar, room: home_office
# obj: blender_jar, room: kitchen
# obj: blender_jar, room: living_room
# obj: blender_jar, room: lobby
# obj: blender_jar, room: playroom
# obj: blender_jar, room: storage_room
# obj: blender_jar, room: television_room
# obj: board_game, room: bathroom
# obj: board_game, room: bedroom
# obj: board_game, room: closet
# obj: board_game, room: corridor
# obj: board_game, room: dining_room
# obj: board_game, room: exercise_room
# obj: board_game, room: garage
# obj: board_game, room: home_office
# obj: board_game, room: kitchen
# obj: board_game, room: living_room
# obj: board_game, room: lobby
# obj: board_game, room: pantry_room
# obj: board_game, room: playroom
# obj: board_game, room: storage_room
# obj: board_game, room: television_room
# obj: board_game, room: utility_room
# obj: book, room: bedroom
# obj: book, room: childs_room
# obj: book, room: dining_room
# obj: book, room: exercise_room
# obj: book, room: garage
# obj: book, room: home_office
# obj: book, room: kitchen
# obj: book, room: lobby
# obj: bookend, room: bathroom
# obj: bookend, room: bedroom
# obj: bookend, room: childs_room
# obj: bookend, room: closet
# obj: bookend, room: corridor
# obj: bookend, room: dining_room
# obj: bookend, room: exercise_room
# obj: bookend, room: garage
# obj: bookend, room: home_office
# obj: bookend, room: kitchen
# obj: bookend, room: living_room
# obj: bookend, room: lobby
# obj: bookend, room: pantry_room
# obj: bookend, room: playroom
# obj: bookend, room: storage_room
# obj: bookend, room: television_room
# obj: bookend, room: utility_room
# obj: bowl, room: bathroom
# obj: bowl, room: bedroom
# obj: bowl, room: childs_room
# obj: bowl, room: closet
# obj: bowl, room: corridor
# obj: bowl, room: exercise_room
# obj: bowl, room: garage
# obj: bowl, room: home_office
# obj: bowl, room: kitchen
# obj: bowl, room: living_room
# obj: bowl, room: lobby
# obj: bowl, room: storage_room
# obj: bowl, room: television_room
# obj: box, room: childs_room
# obj: box, room: closet
# obj: box, room: corridor
# obj: box, room: dining_room
# obj: box, room: exercise_room
# obj: box, room: garage
# obj: box, room: kitchen
# obj: box, room: living_room
# obj: box, room: lobby
# obj: box, room: storage_room
# obj: box, room: television_room
# obj: box, room: utility_room
# obj: bundt_pan, room: bathroom
# obj: bundt_pan, room: bedroom
# obj: bundt_pan, room: childs_room
# obj: bundt_pan, room: closet
# obj: bundt_pan, room: corridor
# obj: bundt_pan, room: dining_room
# obj: bundt_pan, room: exercise_room
# obj: bundt_pan, room: garage
# obj: bundt_pan, room: home_office
# obj: bundt_pan, room: kitchen
# obj: bundt_pan, room: living_room
# obj: bundt_pan, room: lobby
# obj: bundt_pan, room: pantry_room
# obj: bundt_pan, room: playroom
# obj: bundt_pan, room: storage_room
# obj: bundt_pan, room: television_room
# obj: bundt_pan, room: utility_room
# obj: butter_dish, room: bathroom
# obj: butter_dish, room: bedroom
# obj: butter_dish, room: childs_room
# obj: butter_dish, room: closet
# obj: butter_dish, room: corridor
# obj: butter_dish, room: dining_room
# obj: butter_dish, room: exercise_room
# obj: butter_dish, room: garage
# obj: butter_dish, room: home_office
# obj: butter_dish, room: kitchen
# obj: butter_dish, room: living_room
# obj: butter_dish, room: lobby
# obj: butter_dish, room: pantry_room
# obj: butter_dish, room: playroom
# obj: butter_dish, room: storage_room
# obj: butter_dish, room: television_room
# obj: butter_dish, room: utility_room
# obj: cake_mix, room: bathroom
# obj: cake_mix, room: bedroom
# obj: cake_mix, room: childs_room
# obj: cake_mix, room: closet
# obj: cake_mix, room: corridor
# obj: cake_mix, room: exercise_room
# obj: cake_mix, room: garage
# obj: cake_mix, room: home_office
# obj: cake_mix, room: living_room
# obj: cake_mix, room: lobby
# obj: cake_mix, room: playroom
# obj: cake_mix, room: storage_room
# obj: cake_mix, room: television_room
# obj: cake_mix, room: utility_room
# obj: cake_pan, room: bathroom
# obj: cake_pan, room: bedroom
# obj: cake_pan, room: closet
# obj: cake_pan, room: corridor
# obj: cake_pan, room: dining_room
# obj: cake_pan, room: exercise_room
# obj: cake_pan, room: garage
# obj: cake_pan, room: home_office
# obj: cake_pan, room: kitchen
# obj: cake_pan, room: living_room
# obj: cake_pan, room: lobby
# obj: cake_pan, room: pantry_room
# obj: cake_pan, room: playroom
# obj: cake_pan, room: storage_room
# obj: cake_pan, room: television_room
# obj: cake_pan, room: utility_room
# obj: camera, room: bedroom
# obj: camera, room: closet
# obj: camera, room: corridor
# obj: camera, room: exercise_room
# obj: camera, room: garage
# obj: camera, room: home_office
# obj: camera, room: lobby
# obj: camera, room: storage_room
# obj: camera, room: television_room
# obj: can_opener, room: bathroom
# obj: can_opener, room: bedroom
# obj: can_opener, room: childs_room
# obj: can_opener, room: closet
# obj: can_opener, room: corridor
# obj: can_opener, room: dining_room
# obj: can_opener, room: exercise_room
# obj: can_opener, room: garage
# obj: can_opener, room: home_office
# obj: can_opener, room: kitchen
# obj: can_opener, room: living_room
# obj: can_opener, room: lobby
# obj: can_opener, room: playroom
# obj: can_opener, room: storage_room
# obj: can_opener, room: television_room
# obj: can_opener, room: utility_room
# obj: candle_holder, room: bathroom
# obj: candle_holder, room: bedroom
# obj: candle_holder, room: closet
# obj: candle_holder, room: dining_room
# obj: candle_holder, room: exercise_room
# obj: candle_holder, room: garage
# obj: candle_holder, room: home_office
# obj: candle_holder, room: kitchen
# obj: candle_holder, room: pantry_room
# obj: candle_holder, room: playroom
# obj: candy, room: bathroom
# obj: candy, room: bedroom
# obj: candy, room: childs_room
# obj: candy, room: closet
# obj: candy, room: corridor
# obj: candy, room: dining_room
# obj: candy, room: exercise_room
# obj: candy, room: garage
# obj: candy, room: home_office
# obj: candy, room: kitchen
# obj: candy, room: living_room
# obj: candy, room: lobby
# obj: candy, room: pantry_room
# obj: candy, room: storage_room
# obj: candy, room: television_room
# obj: candy_bar, room: bathroom
# obj: candy_bar, room: bedroom
# obj: candy_bar, room: childs_room
# obj: candy_bar, room: closet
# obj: candy_bar, room: corridor
# obj: candy_bar, room: dining_room
# obj: candy_bar, room: exercise_room
# obj: candy_bar, room: garage
# obj: candy_bar, room: home_office
# obj: candy_bar, room: kitchen
# obj: candy_bar, room: living_room
# obj: candy_bar, room: lobby
# obj: candy_bar, room: pantry_room
# obj: candy_bar, room: playroom
# obj: candy_bar, room: storage_room
# obj: candy_bar, room: television_room
# obj: candy_bar, room: utility_room
# obj: canister, room: bedroom
# obj: canister, room: childs_room
# obj: canister, room: closet
# obj: canister, room: corridor
# obj: canister, room: dining_room
# obj: canister, room: exercise_room
# obj: canister, room: garage
# obj: canister, room: kitchen
# obj: canister, room: lobby
# obj: canister, room: pantry_room
# obj: canister, room: storage_room
# obj: canister, room: television_room
# obj: canister, room: utility_room
# obj: card_game, room: bathroom
# obj: card_game, room: childs_room
# obj: card_game, room: closet
# obj: card_game, room: corridor
# obj: card_game, room: dining_room
# obj: card_game, room: exercise_room
# obj: card_game, room: garage
# obj: card_game, room: home_office
# obj: card_game, room: kitchen
# obj: card_game, room: living_room
# obj: card_game, room: lobby
# obj: card_game, room: pantry_room
# obj: card_game, room: playroom
# obj: card_game, room: utility_room
# obj: carrying_case, room: bathroom
# obj: carrying_case, room: bedroom
# obj: carrying_case, room: childs_room
# obj: carrying_case, room: closet
# obj: carrying_case, room: corridor
# obj: carrying_case, room: exercise_room
# obj: carrying_case, room: garage
# obj: carrying_case, room: kitchen
# obj: carrying_case, room: living_room
# obj: carrying_case, room: lobby
# obj: carrying_case, room: television_room
# obj: casserole_dish, room: bathroom
# obj: casserole_dish, room: bedroom
# obj: casserole_dish, room: childs_room
# obj: casserole_dish, room: closet
# obj: casserole_dish, room: corridor
# obj: casserole_dish, room: dining_room
# obj: casserole_dish, room: exercise_room
# obj: casserole_dish, room: garage
# obj: casserole_dish, room: home_office
# obj: casserole_dish, room: kitchen
# obj: casserole_dish, room: living_room
# obj: casserole_dish, room: lobby
# obj: casserole_dish, room: pantry_room
# obj: casserole_dish, room: playroom
# obj: casserole_dish, room: storage_room
# obj: casserole_dish, room: television_room
# obj: casserole_dish, room: utility_room
# obj: cereal, room: bathroom
# obj: cereal, room: bedroom
# obj: cereal, room: childs_room
# obj: cereal, room: closet
# obj: cereal, room: corridor
# obj: cereal, room: dining_room
# obj: cereal, room: exercise_room
# obj: cereal, room: garage
# obj: cereal, room: home_office
# obj: cereal, room: kitchen
# obj: cereal, room: living_room
# obj: cereal, room: lobby
# obj: cereal, room: pantry_room
# obj: cereal, room: playroom
# obj: cereal, room: storage_room
# obj: cereal, room: television_room
# obj: cereal, room: utility_room
# obj: chain, room: bathroom
# obj: chain, room: bedroom
# obj: chain, room: closet
# obj: chain, room: dining_room
# obj: chain, room: exercise_room
# obj: chain, room: garage
# obj: chain, room: home_office
# obj: chain, room: living_room
# obj: chain, room: lobby
# obj: chain, room: playroom
# obj: chain, room: storage_room
# obj: chocolate, room: bathroom
# obj: chocolate, room: bedroom
# obj: chocolate, room: childs_room
# obj: chocolate, room: closet
# obj: chocolate, room: corridor
# obj: chocolate, room: dining_room
# obj: chocolate, room: exercise_room
# obj: chocolate, room: garage
# obj: chocolate, room: home_office
# obj: chocolate, room: kitchen
# obj: chocolate, room: living_room
# obj: chocolate, room: lobby
# obj: chocolate, room: pantry_room
# obj: chocolate, room: playroom
# obj: chocolate, room: storage_room
# obj: chocolate, room: television_room
# obj: chocolate, room: utility_room
# obj: chocolate_box, room: bathroom
# obj: chocolate_box, room: bedroom
# obj: chocolate_box, room: childs_room
# obj: chocolate_box, room: closet
# obj: chocolate_box, room: corridor
# obj: chocolate_box, room: dining_room
# obj: chocolate_box, room: exercise_room
# obj: chocolate_box, room: garage
# obj: chocolate_box, room: home_office
# obj: chocolate_box, room: living_room
# obj: chocolate_box, room: lobby
# obj: chocolate_box, room: playroom
# obj: chocolate_box, room: television_room
# obj: chocolate_box, room: utility_room
# obj: chocolate_milk_pods, room: bathroom
# obj: chocolate_milk_pods, room: bedroom
# obj: chocolate_milk_pods, room: childs_room
# obj: chocolate_milk_pods, room: closet
# obj: chocolate_milk_pods, room: corridor
# obj: chocolate_milk_pods, room: dining_room
# obj: chocolate_milk_pods, room: exercise_room
# obj: chocolate_milk_pods, room: garage
# obj: chocolate_milk_pods, room: home_office
# obj: chocolate_milk_pods, room: kitchen
# obj: chocolate_milk_pods, room: living_room
# obj: chocolate_milk_pods, room: lobby
# obj: chocolate_milk_pods, room: pantry_room
# obj: chocolate_milk_pods, room: playroom
# obj: chocolate_milk_pods, room: storage_room
# obj: chocolate_milk_pods, room: television_room
# obj: chocolate_milk_pods, room: utility_room
# obj: chocolate_powder, room: bathroom
# obj: chocolate_powder, room: bedroom
# obj: chocolate_powder, room: childs_room
# obj: chocolate_powder, room: closet
# obj: chocolate_powder, room: corridor
# obj: chocolate_powder, room: dining_room
# obj: chocolate_powder, room: exercise_room
# obj: chocolate_powder, room: garage
# obj: chocolate_powder, room: home_office
# obj: chocolate_powder, room: kitchen
# obj: chocolate_powder, room: living_room
# obj: chocolate_powder, room: lobby
# obj: chocolate_powder, room: pantry_room
# obj: chocolate_powder, room: playroom
# obj: chocolate_powder, room: storage_room
# obj: chocolate_powder, room: television_room
# obj: chocolate_powder, room: utility_room
# obj: chopping_board, room: bathroom
# obj: chopping_board, room: bedroom
# obj: chopping_board, room: childs_room
# obj: chopping_board, room: closet
# obj: chopping_board, room: corridor
# obj: chopping_board, room: dining_room
# obj: chopping_board, room: exercise_room
# obj: chopping_board, room: garage
# obj: chopping_board, room: home_office
# obj: chopping_board, room: kitchen
# obj: chopping_board, room: living_room
# obj: chopping_board, room: playroom
# obj: chopping_board, room: storage_room
# obj: chopping_board, room: television_room
# obj: clamp, room: bedroom
# obj: clamp, room: childs_room
# obj: clamp, room: closet
# obj: clamp, room: dining_room
# obj: clamp, room: exercise_room
# obj: clamp, room: garage
# obj: clamp, room: lobby
# obj: clamp, room: pantry_room
# obj: clamp, room: playroom
# obj: clamp, room: television_room
# obj: clamp, room: utility_room
# obj: clay, room: bathroom
# obj: clay, room: bedroom
# obj: clay, room: childs_room
# obj: clay, room: closet
# obj: clay, room: corridor
# obj: clay, room: dining_room
# obj: clay, room: exercise_room
# obj: clay, room: garage
# obj: clay, room: home_office
# obj: clay, room: kitchen
# obj: clay, room: living_room
# obj: clay, room: lobby
# obj: clay, room: playroom
# obj: clay, room: storage_room
# obj: clay, room: utility_room
# obj: clock, room: bathroom
# obj: clock, room: bedroom
# obj: clock, room: closet
# obj: clock, room: dining_room
# obj: clock, room: exercise_room
# obj: clock, room: garage
# obj: clock, room: home_office
# obj: clock, room: living_room
# obj: clock, room: lobby
# obj: clock, room: pantry_room
# obj: clock, room: playroom
# obj: clock, room: television_room
# obj: clock, room: utility_room
# obj: cloth, room: bedroom
# obj: cloth, room: closet
# obj: cloth, room: corridor
# obj: cloth, room: dining_room
# obj: cloth, room: exercise_room
# obj: cloth, room: garage
# obj: cloth, room: kitchen
# obj: cloth, room: lobby
# obj: cloth, room: television_room
# obj: cloth, room: utility_room
# obj: coffee_beans, room: bathroom
# obj: coffee_beans, room: bedroom
# obj: coffee_beans, room: childs_room
# obj: coffee_beans, room: closet
# obj: coffee_beans, room: corridor
# obj: coffee_beans, room: dining_room
# obj: coffee_beans, room: exercise_room
# obj: coffee_beans, room: garage
# obj: coffee_beans, room: home_office
# obj: coffee_beans, room: kitchen
# obj: coffee_beans, room: living_room
# obj: coffee_beans, room: lobby
# obj: coffee_beans, room: pantry_room
# obj: coffee_beans, room: playroom
# obj: coffee_beans, room: storage_room
# obj: coffee_beans, room: television_room
# obj: coffee_pods, room: bathroom
# obj: coffee_pods, room: bedroom
# obj: coffee_pods, room: childs_room
# obj: coffee_pods, room: closet
# obj: coffee_pods, room: corridor
# obj: coffee_pods, room: dining_room
# obj: coffee_pods, room: exercise_room
# obj: coffee_pods, room: garage
# obj: coffee_pods, room: home_office
# obj: coffee_pods, room: kitchen
# obj: coffee_pods, room: living_room
# obj: coffee_pods, room: lobby
# obj: coffee_pods, room: pantry_room
# obj: coffee_pods, room: playroom
# obj: coffee_pods, room: television_room
# obj: coffee_pods, room: utility_room
# obj: coffeemaker, room: bathroom
# obj: coffeemaker, room: bedroom
# obj: coffeemaker, room: childs_room
# obj: coffeemaker, room: closet
# obj: coffeemaker, room: corridor
# obj: coffeemaker, room: dining_room
# obj: coffeemaker, room: exercise_room
# obj: coffeemaker, room: garage
# obj: coffeemaker, room: home_office
# obj: coffeemaker, room: kitchen
# obj: coffeemaker, room: living_room
# obj: coffeemaker, room: lobby
# obj: coffeemaker, room: pantry_room
# obj: coffeemaker, room: playroom
# obj: coffeemaker, room: storage_room
# obj: coffeemaker, room: television_room
# obj: coffeemaker, room: utility_room
# obj: colored_wood_blocks, room: closet
# obj: colored_wood_blocks, room: corridor
# obj: colored_wood_blocks, room: dining_room
# obj: colored_wood_blocks, room: exercise_room
# obj: colored_wood_blocks, room: garage
# obj: colored_wood_blocks, room: home_office
# obj: colored_wood_blocks, room: kitchen
# obj: colored_wood_blocks, room: living_room
# obj: colored_wood_blocks, room: lobby
# obj: colored_wood_blocks, room: television_room
# obj: colored_wood_blocks, room: utility_room
# obj: condiment, room: bathroom
# obj: condiment, room: bedroom
# obj: condiment, room: childs_room
# obj: condiment, room: closet
# obj: condiment, room: corridor
# obj: condiment, room: dining_room
# obj: condiment, room: exercise_room
# obj: condiment, room: garage
# obj: condiment, room: home_office
# obj: condiment, room: living_room
# obj: condiment, room: lobby
# obj: condiment, room: playroom
# obj: condiment, room: storage_room
# obj: condiment, room: television_room
# obj: condiment, room: utility_room
# obj: cracker_box, room: bathroom
# obj: cracker_box, room: bedroom
# obj: cracker_box, room: childs_room
# obj: cracker_box, room: closet
# obj: cracker_box, room: corridor
# obj: cracker_box, room: dining_room
# obj: cracker_box, room: exercise_room
# obj: cracker_box, room: garage
# obj: cracker_box, room: home_office
# obj: cracker_box, room: lobby
# obj: cracker_box, room: pantry_room
# obj: cracker_box, room: playroom
# obj: cracker_box, room: television_room
# obj: cracker_box, room: utility_room
# obj: crayon, room: bathroom
# obj: crayon, room: bedroom
# obj: crayon, room: childs_room
# obj: crayon, room: closet
# obj: crayon, room: corridor
# obj: crayon, room: dining_room
# obj: crayon, room: exercise_room
# obj: crayon, room: garage
# obj: crayon, room: home_office
# obj: crayon, room: living_room
# obj: crayon, room: lobby
# obj: crayon, room: pantry_room
# obj: crayon, room: television_room
# obj: crayon, room: utility_room
# obj: cube_storage_box, room: bathroom
# obj: cube_storage_box, room: bedroom
# obj: cube_storage_box, room: childs_room
# obj: cube_storage_box, room: closet
# obj: cube_storage_box, room: dining_room
# obj: cube_storage_box, room: exercise_room
# obj: cube_storage_box, room: garage
# obj: cube_storage_box, room: home_office
# obj: cube_storage_box, room: kitchen
# obj: cube_storage_box, room: living_room
# obj: cube_storage_box, room: lobby
# obj: cube_storage_box, room: pantry_room
# obj: cube_storage_box, room: playroom
# obj: cube_storage_box, room: television_room
# obj: cube_storage_box, room: utility_room
# obj: cup, room: bedroom
# obj: cup, room: closet
# obj: cup, room: dining_room
# obj: cup, room: exercise_room
# obj: cup, room: garage
# obj: cup, room: kitchen
# obj: cup, room: playroom
# obj: cup, room: television_room
# obj: cup, room: utility_room
# obj: cushion, room: bathroom
# obj: cushion, room: childs_room
# obj: cushion, room: closet
# obj: cushion, room: corridor
# obj: cushion, room: dining_room
# obj: cushion, room: exercise_room
# obj: cushion, room: garage
# obj: cushion, room: kitchen
# obj: cushion, room: pantry_room
# obj: cushion, room: storage_room
# obj: cushion, room: utility_room
# obj: desk_caddy, room: bathroom
# obj: desk_caddy, room: bedroom
# obj: desk_caddy, room: childs_room
# obj: desk_caddy, room: closet
# obj: desk_caddy, room: corridor
# obj: desk_caddy, room: dining_room
# obj: desk_caddy, room: exercise_room
# obj: desk_caddy, room: garage
# obj: desk_caddy, room: home_office
# obj: desk_caddy, room: living_room
# obj: desk_caddy, room: lobby
# obj: desk_caddy, room: pantry_room
# obj: desk_caddy, room: playroom
# obj: desk_caddy, room: storage_room
# obj: desk_caddy, room: television_room
# obj: desk_caddy, room: utility_room
# obj: diaper_pack, room: bedroom
# obj: diaper_pack, room: childs_room
# obj: diaper_pack, room: closet
# obj: diaper_pack, room: corridor
# obj: diaper_pack, room: dining_room
# obj: diaper_pack, room: exercise_room
# obj: diaper_pack, room: garage
# obj: diaper_pack, room: home_office
# obj: diaper_pack, room: kitchen
# obj: diaper_pack, room: lobby
# obj: diaper_pack, room: pantry_room
# obj: diaper_pack, room: playroom
# obj: diaper_pack, room: television_room
# obj: diaper_pack, room: utility_room
# obj: dietary_supplement, room: bathroom
# obj: dietary_supplement, room: bedroom
# obj: dietary_supplement, room: childs_room
# obj: dietary_supplement, room: closet
# obj: dietary_supplement, room: corridor
# obj: dietary_supplement, room: dining_room
# obj: dietary_supplement, room: exercise_room
# obj: dietary_supplement, room: garage
# obj: dietary_supplement, room: home_office
# obj: dietary_supplement, room: kitchen
# obj: dietary_supplement, room: living_room
# obj: dietary_supplement, room: lobby
# obj: dietary_supplement, room: pantry_room
# obj: dietary_supplement, room: playroom
# obj: dietary_supplement, room: storage_room
# obj: dietary_supplement, room: television_room
# obj: dish_drainer, room: bathroom
# obj: dish_drainer, room: bedroom
# obj: dish_drainer, room: childs_room
# obj: dish_drainer, room: closet
# obj: dish_drainer, room: corridor
# obj: dish_drainer, room: dining_room
# obj: dish_drainer, room: exercise_room
# obj: dish_drainer, room: garage
# obj: dish_drainer, room: home_office
# obj: dish_drainer, room: kitchen
# obj: dish_drainer, room: living_room
# obj: dish_drainer, room: lobby
# obj: dish_drainer, room: pantry_room
# obj: dish_drainer, room: playroom
# obj: dish_drainer, room: storage_room
# obj: dish_drainer, room: television_room
# obj: dish_drainer, room: utility_room
# obj: dishtowel, room: bathroom
# obj: dishtowel, room: bedroom
# obj: dishtowel, room: childs_room
# obj: dishtowel, room: closet
# obj: dishtowel, room: corridor
# obj: dishtowel, room: dining_room
# obj: dishtowel, room: exercise_room
# obj: dishtowel, room: garage
# obj: dishtowel, room: kitchen
# obj: dishtowel, room: living_room
# obj: dishtowel, room: lobby
# obj: dishtowel, room: playroom
# obj: dishtowel, room: storage_room
# obj: dishtowel, room: television_room
# obj: dishtowel, room: utility_room
# obj: dispensing_closure, room: childs_room
# obj: dispensing_closure, room: closet
# obj: dispensing_closure, room: corridor
# obj: dispensing_closure, room: dining_room
# obj: dispensing_closure, room: exercise_room
# obj: dispensing_closure, room: garage
# obj: dispensing_closure, room: living_room
# obj: dispensing_closure, room: lobby
# obj: dispensing_closure, room: pantry_room
# obj: dispensing_closure, room: playroom
# obj: dispensing_closure, room: storage_room
# obj: dog_bowl, room: bathroom
# obj: dog_bowl, room: bedroom
# obj: dog_bowl, room: childs_room
# obj: dog_bowl, room: closet
# obj: dog_bowl, room: corridor
# obj: dog_bowl, room: dining_room
# obj: dog_bowl, room: exercise_room
# obj: dog_bowl, room: garage
# obj: dog_bowl, room: home_office
# obj: dog_bowl, room: kitchen
# obj: dog_bowl, room: living_room
# obj: dog_bowl, room: lobby
# obj: dog_bowl, room: pantry_room
# obj: dog_bowl, room: playroom
# obj: dog_bowl, room: storage_room
# obj: dog_bowl, room: television_room
# obj: dog_chew_toy, room: bathroom
# obj: dog_chew_toy, room: bedroom
# obj: dog_chew_toy, room: childs_room
# obj: dog_chew_toy, room: closet
# obj: dog_chew_toy, room: corridor
# obj: dog_chew_toy, room: dining_room
# obj: dog_chew_toy, room: exercise_room
# obj: dog_chew_toy, room: garage
# obj: dog_chew_toy, room: kitchen
# obj: dog_chew_toy, room: living_room
# obj: dog_chew_toy, room: lobby
# obj: dog_chew_toy, room: playroom
# obj: dog_chew_toy, room: television_room
# obj: dollhouse_toy, room: bathroom
# obj: dollhouse_toy, room: bedroom
# obj: dollhouse_toy, room: childs_room
# obj: dollhouse_toy, room: closet
# obj: dollhouse_toy, room: corridor
# obj: dollhouse_toy, room: dining_room
# obj: dollhouse_toy, room: exercise_room
# obj: dollhouse_toy, room: garage
# obj: dollhouse_toy, room: home_office
# obj: dollhouse_toy, room: kitchen
# obj: dollhouse_toy, room: living_room
# obj: dollhouse_toy, room: lobby
# obj: dollhouse_toy, room: pantry_room
# obj: dollhouse_toy, room: playroom
# obj: dollhouse_toy, room: storage_room
# obj: dollhouse_toy, room: television_room
# obj: dollhouse_toy, room: utility_room
# obj: donut, room: bathroom
# obj: donut, room: bedroom
# obj: donut, room: childs_room
# obj: donut, room: closet
# obj: donut, room: corridor
# obj: donut, room: dining_room
# obj: donut, room: exercise_room
# obj: donut, room: garage
# obj: donut, room: home_office
# obj: donut, room: kitchen
# obj: donut, room: living_room
# obj: donut, room: lobby
# obj: donut, room: pantry_room
# obj: donut, room: playroom
# obj: donut, room: storage_room
# obj: donut, room: television_room
# obj: donut, room: utility_room
# obj: drink_coaster, room: bathroom
# obj: drink_coaster, room: bedroom
# obj: drink_coaster, room: closet
# obj: drink_coaster, room: corridor
# obj: drink_coaster, room: exercise_room
# obj: drink_coaster, room: garage
# obj: drink_coaster, room: home_office
# obj: drink_coaster, room: kitchen
# obj: drink_coaster, room: living_room
# obj: drink_coaster, room: lobby
# obj: drink_coaster, room: pantry_room
# obj: drink_coaster, room: storage_room
# obj: drink_coaster, room: television_room
# obj: duct_tape, room: bathroom
# obj: duct_tape, room: bedroom
# obj: duct_tape, room: childs_room
# obj: duct_tape, room: closet
# obj: duct_tape, room: corridor
# obj: duct_tape, room: dining_room
# obj: duct_tape, room: exercise_room
# obj: duct_tape, room: garage
# obj: duct_tape, room: home_office
# obj: duct_tape, room: living_room
# obj: duct_tape, room: lobby
# obj: duct_tape, room: playroom
# obj: duct_tape, room: storage_room
# obj: duct_tape, room: television_room
# obj: duct_tape, room: utility_room
# obj: dumbbell, room: bathroom
# obj: dumbbell, room: bedroom
# obj: dumbbell, room: childs_room
# obj: dumbbell, room: closet
# obj: dumbbell, room: dining_room
# obj: dumbbell, room: exercise_room
# obj: dumbbell, room: garage
# obj: dumbbell, room: kitchen
# obj: dumbbell, room: lobby
# obj: dumbbell, room: pantry_room
# obj: dumbbell, room: television_room
# obj: dumbbell_rack, room: bathroom
# obj: dumbbell_rack, room: bedroom
# obj: dumbbell_rack, room: childs_room
# obj: dumbbell_rack, room: closet
# obj: dumbbell_rack, room: corridor
# obj: dumbbell_rack, room: dining_room
# obj: dumbbell_rack, room: exercise_room
# obj: dumbbell_rack, room: garage
# obj: dumbbell_rack, room: home_office
# obj: dumbbell_rack, room: living_room
# obj: dumbbell_rack, room: lobby
# obj: dumbbell_rack, room: playroom
# obj: dumbbell_rack, room: storage_room
# obj: dumbbell_rack, room: television_room
# obj: dustpan_and_brush, room: bathroom
# obj: dustpan_and_brush, room: bedroom
# obj: dustpan_and_brush, room: childs_room
# obj: dustpan_and_brush, room: closet
# obj: dustpan_and_brush, room: corridor
# obj: dustpan_and_brush, room: dining_room
# obj: dustpan_and_brush, room: exercise_room
# obj: dustpan_and_brush, room: garage
# obj: dustpan_and_brush, room: home_office
# obj: dustpan_and_brush, room: kitchen
# obj: dustpan_and_brush, room: living_room
# obj: dustpan_and_brush, room: lobby
# obj: dustpan_and_brush, room: pantry_room
# obj: dustpan_and_brush, room: playroom
# obj: dustpan_and_brush, room: storage_room
# obj: dustpan_and_brush, room: television_room
# obj: dustpan_and_brush, room: utility_room
# obj: dutch_oven, room: bathroom
# obj: dutch_oven, room: bedroom
# obj: dutch_oven, room: closet
# obj: dutch_oven, room: corridor
# obj: dutch_oven, room: exercise_room
# obj: dutch_oven, room: garage
# obj: dutch_oven, room: home_office
# obj: dutch_oven, room: kitchen
# obj: dutch_oven, room: lobby
# obj: dutch_oven, room: playroom
# obj: easter_basket, room: bathroom
# obj: easter_basket, room: bedroom
# obj: easter_basket, room: childs_room
# obj: easter_basket, room: closet
# obj: easter_basket, room: corridor
# obj: easter_basket, room: dining_room
# obj: easter_basket, room: exercise_room
# obj: easter_basket, room: garage
# obj: easter_basket, room: home_office
# obj: easter_basket, room: kitchen
# obj: easter_basket, room: living_room
# obj: easter_basket, room: lobby
# obj: easter_basket, room: pantry_room
# obj: easter_basket, room: storage_room
# obj: easter_basket, room: utility_room
# obj: electric_heater, room: bathroom
# obj: electric_heater, room: bedroom
# obj: electric_heater, room: childs_room
# obj: electric_heater, room: closet
# obj: electric_heater, room: corridor
# obj: electric_heater, room: dining_room
# obj: electric_heater, room: exercise_room
# obj: electric_heater, room: garage
# obj: electric_heater, room: home_office
# obj: electric_heater, room: kitchen
# obj: electric_heater, room: living_room
# obj: electric_heater, room: lobby
# obj: electric_heater, room: playroom
# obj: electric_toothbrush, room: bedroom
# obj: electric_toothbrush, room: childs_room
# obj: electric_toothbrush, room: closet
# obj: electric_toothbrush, room: corridor
# obj: electric_toothbrush, room: dining_room
# obj: electric_toothbrush, room: exercise_room
# obj: electric_toothbrush, room: garage
# obj: electric_toothbrush, room: home_office
# obj: electric_toothbrush, room: kitchen
# obj: electric_toothbrush, room: living_room
# obj: electric_toothbrush, room: lobby
# obj: electric_toothbrush, room: playroom
# obj: electric_toothbrush, room: television_room
# obj: electric_toothbrush, room: utility_room
# obj: electronic_adapter, room: bedroom
# obj: electronic_adapter, room: closet
# obj: electronic_adapter, room: exercise_room
# obj: electronic_adapter, room: garage
# obj: electronic_adapter, room: home_office
# obj: electronic_adapter, room: lobby
# obj: electronic_adapter, room: pantry_room
# obj: electronic_adapter, room: playroom
# obj: electronic_cable, room: bedroom
# obj: electronic_cable, room: childs_room
# obj: electronic_cable, room: closet
# obj: electronic_cable, room: corridor
# obj: electronic_cable, room: dining_room
# obj: electronic_cable, room: exercise_room
# obj: electronic_cable, room: garage
# obj: electronic_cable, room: home_office
# obj: electronic_cable, room: living_room
# obj: electronic_cable, room: lobby
# obj: electronic_cable, room: playroom
# obj: electronic_cable, room: storage_room
# obj: face_moisturizer, room: bathroom
# obj: face_moisturizer, room: bedroom
# obj: face_moisturizer, room: childs_room
# obj: face_moisturizer, room: closet
# obj: face_moisturizer, room: corridor
# obj: face_moisturizer, room: dining_room
# obj: face_moisturizer, room: exercise_room
# obj: face_moisturizer, room: garage
# obj: face_moisturizer, room: home_office
# obj: face_moisturizer, room: kitchen
# obj: face_moisturizer, room: living_room
# obj: face_moisturizer, room: lobby
# obj: face_moisturizer, room: pantry_room
# obj: face_moisturizer, room: playroom
# obj: face_moisturizer, room: storage_room
# obj: face_moisturizer, room: television_room
# obj: face_moisturizer, room: utility_room
# obj: file_sorter, room: bathroom
# obj: file_sorter, room: bedroom
# obj: file_sorter, room: childs_room
# obj: file_sorter, room: closet
# obj: file_sorter, room: corridor
# obj: file_sorter, room: dining_room
# obj: file_sorter, room: exercise_room
# obj: file_sorter, room: garage
# obj: file_sorter, room: home_office
# obj: file_sorter, room: kitchen
# obj: file_sorter, room: living_room
# obj: file_sorter, room: lobby
# obj: file_sorter, room: pantry_room
# obj: file_sorter, room: playroom
# obj: file_sorter, room: storage_room
# obj: file_sorter, room: television_room
# obj: file_sorter, room: utility_room
# obj: fingerpaint, room: bathroom
# obj: fingerpaint, room: bedroom
# obj: fingerpaint, room: childs_room
# obj: fingerpaint, room: closet
# obj: fingerpaint, room: corridor
# obj: fingerpaint, room: dining_room
# obj: fingerpaint, room: exercise_room
# obj: fingerpaint, room: garage
# obj: fingerpaint, room: home_office
# obj: fingerpaint, room: kitchen
# obj: fingerpaint, room: living_room
# obj: fingerpaint, room: lobby
# obj: fingerpaint, room: pantry_room
# obj: fingerpaint, room: playroom
# obj: fingerpaint, room: storage_room
# obj: fingerpaint, room: television_room
# obj: fingerpaint, room: utility_room
# obj: fitness_tracker_wristband, room: bathroom
# obj: fitness_tracker_wristband, room: bedroom
# obj: fitness_tracker_wristband, room: closet
# obj: fitness_tracker_wristband, room: corridor
# obj: fitness_tracker_wristband, room: dining_room
# obj: fitness_tracker_wristband, room: exercise_room
# obj: fitness_tracker_wristband, room: garage
# obj: fitness_tracker_wristband, room: home_office
# obj: fitness_tracker_wristband, room: kitchen
# obj: fitness_tracker_wristband, room: living_room
# obj: fitness_tracker_wristband, room: lobby
# obj: fitness_tracker_wristband, room: pantry_room
# obj: fitness_tracker_wristband, room: playroom
# obj: fitness_tracker_wristband, room: storage_room
# obj: fitness_tracker_wristband, room: television_room
# obj: fitness_tracker_wristband, room: utility_room
# obj: flashlight, room: childs_room
# obj: flashlight, room: closet
# obj: flashlight, room: corridor
# obj: flashlight, room: dining_room
# obj: flashlight, room: exercise_room
# obj: flashlight, room: garage
# obj: flashlight, room: living_room
# obj: flashlight, room: lobby
# obj: flashlight, room: pantry_room
# obj: flashlight, room: playroom
# obj: flashlight, room: television_room
# obj: flashlight, room: utility_room
# obj: flat_screwdriver, room: childs_room
# obj: flat_screwdriver, room: closet
# obj: flat_screwdriver, room: corridor
# obj: flat_screwdriver, room: dining_room
# obj: flat_screwdriver, room: exercise_room
# obj: flat_screwdriver, room: garage
# obj: flat_screwdriver, room: kitchen
# obj: flat_screwdriver, room: living_room
# obj: flat_screwdriver, room: lobby
# obj: flat_screwdriver, room: playroom
# obj: flat_screwdriver, room: storage_room
# obj: flat_screwdriver, room: television_room
# obj: flat_screwdriver, room: utility_room
# obj: foam_brick, room: bathroom
# obj: foam_brick, room: bedroom
# obj: foam_brick, room: closet
# obj: foam_brick, room: dining_room
# obj: foam_brick, room: exercise_room
# obj: foam_brick, room: garage
# obj: foam_brick, room: home_office
# obj: foam_brick, room: pantry_room
# obj: foam_brick, room: television_room
# obj: foam_brick, room: utility_room
# obj: folder, room: bedroom
# obj: folder, room: childs_room
# obj: folder, room: closet
# obj: folder, room: corridor
# obj: folder, room: exercise_room
# obj: folder, room: garage
# obj: folder, room: kitchen
# obj: folder, room: lobby
# obj: folder, room: pantry_room
# obj: folder, room: playroom
# obj: folder, room: storage_room
# obj: folder, room: utility_room
# obj: fondant, room: bathroom
# obj: fondant, room: bedroom
# obj: fondant, room: childs_room
# obj: fondant, room: closet
# obj: fondant, room: corridor
# obj: fondant, room: dining_room
# obj: fondant, room: exercise_room
# obj: fondant, room: garage
# obj: fondant, room: home_office
# obj: fondant, room: kitchen
# obj: fondant, room: living_room
# obj: fondant, room: lobby
# obj: fondant, room: pantry_room
# obj: fondant, room: playroom
# obj: fondant, room: storage_room
# obj: fondant, room: television_room
# obj: fondant, room: utility_room
# obj: fork, room: bedroom
# obj: fork, room: childs_room
# obj: fork, room: closet
# obj: fork, room: corridor
# obj: fork, room: dining_room
# obj: fork, room: exercise_room
# obj: fork, room: garage
# obj: fork, room: home_office
# obj: fork, room: kitchen
# obj: fork, room: living_room
# obj: fork, room: lobby
# obj: fork, room: pantry_room
# obj: fork, room: playroom
# obj: fork, room: storage_room
# obj: fork, room: television_room
# obj: fork, room: utility_room
# obj: fruit_snack, room: bathroom
# obj: fruit_snack, room: bedroom
# obj: fruit_snack, room: childs_room
# obj: fruit_snack, room: closet
# obj: fruit_snack, room: corridor
# obj: fruit_snack, room: dining_room
# obj: fruit_snack, room: exercise_room
# obj: fruit_snack, room: garage
# obj: fruit_snack, room: home_office
# obj: fruit_snack, room: kitchen
# obj: fruit_snack, room: living_room
# obj: fruit_snack, room: lobby
# obj: fruit_snack, room: playroom
# obj: fruit_snack, room: storage_room
# obj: fruit_snack, room: television_room
# obj: fruit_snack, room: utility_room
# obj: gelatin_box, room: bathroom
# obj: gelatin_box, room: bedroom
# obj: gelatin_box, room: childs_room
# obj: gelatin_box, room: closet
# obj: gelatin_box, room: corridor
# obj: gelatin_box, room: dining_room
# obj: gelatin_box, room: exercise_room
# obj: gelatin_box, room: garage
# obj: gelatin_box, room: home_office
# obj: gelatin_box, room: living_room
# obj: gelatin_box, room: lobby
# obj: gelatin_box, room: pantry_room
# obj: gelatin_box, room: playroom
# obj: gelatin_box, room: television_room
# obj: gloves, room: bathroom
# obj: gloves, room: childs_room
# obj: gloves, room: closet
# obj: gloves, room: corridor
# obj: gloves, room: dining_room
# obj: gloves, room: exercise_room
# obj: gloves, room: garage
# obj: gloves, room: home_office
# obj: gloves, room: living_room
# obj: gloves, room: lobby
# obj: gloves, room: pantry_room
# obj: gloves, room: playroom
# obj: gloves, room: storage_room
# obj: gloves, room: television_room
# obj: gloves, room: utility_room
# obj: golf_ball, room: bathroom
# obj: golf_ball, room: bedroom
# obj: golf_ball, room: closet
# obj: golf_ball, room: corridor
# obj: golf_ball, room: dining_room
# obj: golf_ball, room: exercise_room
# obj: golf_ball, room: garage
# obj: golf_ball, room: kitchen
# obj: golf_ball, room: living_room
# obj: golf_ball, room: lobby
# obj: golf_ball, room: pantry_room
# obj: golf_ball, room: storage_room
# obj: golf_ball, room: television_room
# obj: graphics_card, room: bathroom
# obj: graphics_card, room: bedroom
# obj: graphics_card, room: childs_room
# obj: graphics_card, room: closet
# obj: graphics_card, room: corridor
# obj: graphics_card, room: dining_room
# obj: graphics_card, room: exercise_room
# obj: graphics_card, room: garage
# obj: graphics_card, room: home_office
# obj: graphics_card, room: kitchen
# obj: graphics_card, room: living_room
# obj: graphics_card, room: lobby
# obj: graphics_card, room: playroom
# obj: graphics_card, room: storage_room
# obj: graphics_card, room: television_room
# obj: graphics_card, room: utility_room
# obj: hair_color, room: bathroom
# obj: hair_color, room: bedroom
# obj: hair_color, room: childs_room
# obj: hair_color, room: closet
# obj: hair_color, room: corridor
# obj: hair_color, room: dining_room
# obj: hair_color, room: exercise_room
# obj: hair_color, room: garage
# obj: hair_color, room: home_office
# obj: hair_color, room: kitchen
# obj: hair_color, room: living_room
# obj: hair_color, room: lobby
# obj: hair_color, room: pantry_room
# obj: hair_color, room: playroom
# obj: hair_color, room: storage_room
# obj: hair_color, room: television_room
# obj: hair_color, room: utility_room
# obj: hair_conditioner, room: bathroom
# obj: hair_conditioner, room: bedroom
# obj: hair_conditioner, room: childs_room
# obj: hair_conditioner, room: closet
# obj: hair_conditioner, room: corridor
# obj: hair_conditioner, room: dining_room
# obj: hair_conditioner, room: exercise_room
# obj: hair_conditioner, room: garage
# obj: hair_conditioner, room: home_office
# obj: hair_conditioner, room: kitchen
# obj: hair_conditioner, room: living_room
# obj: hair_conditioner, room: lobby
# obj: hair_conditioner, room: pantry_room
# obj: hair_conditioner, room: playroom
# obj: hair_conditioner, room: storage_room
# obj: hair_conditioner, room: utility_room
# obj: hair_dryer, room: bathroom
# obj: hair_dryer, room: bedroom
# obj: hair_dryer, room: childs_room
# obj: hair_dryer, room: closet
# obj: hair_dryer, room: corridor
# obj: hair_dryer, room: dining_room
# obj: hair_dryer, room: exercise_room
# obj: hair_dryer, room: garage
# obj: hair_dryer, room: home_office
# obj: hair_dryer, room: kitchen
# obj: hair_dryer, room: living_room
# obj: hair_dryer, room: lobby
# obj: hair_dryer, room: pantry_room
# obj: hair_dryer, room: playroom
# obj: hair_dryer, room: television_room
# obj: hair_dryer, room: utility_room
# obj: hair_straightener, room: bathroom
# obj: hair_straightener, room: bedroom
# obj: hair_straightener, room: childs_room
# obj: hair_straightener, room: closet
# obj: hair_straightener, room: corridor
# obj: hair_straightener, room: dining_room
# obj: hair_straightener, room: exercise_room
# obj: hair_straightener, room: garage
# obj: hair_straightener, room: home_office
# obj: hair_straightener, room: kitchen
# obj: hair_straightener, room: living_room
# obj: hair_straightener, room: lobby
# obj: hair_straightener, room: playroom
# obj: hair_straightener, room: storage_room
# obj: hair_straightener, room: television_room
# obj: hair_straightener, room: utility_room
# obj: hammer, room: closet
# obj: hammer, room: corridor
# obj: hammer, room: dining_room
# obj: hammer, room: exercise_room
# obj: hammer, room: garage
# obj: hammer, room: living_room
# obj: hammer, room: utility_room
# obj: hand_bell, room: bathroom
# obj: hand_bell, room: bedroom
# obj: hand_bell, room: childs_room
# obj: hand_bell, room: closet
# obj: hand_bell, room: corridor
# obj: hand_bell, room: dining_room
# obj: hand_bell, room: exercise_room
# obj: hand_bell, room: garage
# obj: hand_bell, room: home_office
# obj: hand_bell, room: kitchen
# obj: hand_bell, room: living_room
# obj: hand_bell, room: lobby
# obj: hand_bell, room: pantry_room
# obj: hand_bell, room: playroom
# obj: hand_bell, room: storage_room
# obj: hand_bell, room: television_room
# obj: hand_bell, room: utility_room
# obj: handbag, room: bathroom
# obj: handbag, room: childs_room
# obj: handbag, room: closet
# obj: handbag, room: corridor
# obj: handbag, room: dining_room
# obj: handbag, room: exercise_room
# obj: handbag, room: garage
# obj: handbag, room: home_office
# obj: handbag, room: kitchen
# obj: handbag, room: living_room
# obj: handbag, room: lobby
# obj: handbag, room: pantry_room
# obj: handbag, room: playroom
# obj: handbag, room: utility_room
# obj: hard_drive, room: bathroom
# ...
# obj: toothbrush_pack, room: playroom
# obj: toothbrush_pack, room: storage_room
# obj: toothbrush_pack, room: television_room
# obj: toothbrush_pack, room: utility_room
# obj: towel, room: bedroom
# obj: towel, room: childs_room
# obj: towel, room: closet
# obj: towel, room: corridor
# obj: towel, room: exercise_room
# obj: towel, room: garage
# obj: towel, room: living_room
# obj: towel, room: lobby
# obj: towel, room: pantry_room
# obj: towel, room: storage_room
# obj: towel, room: television_room
# obj: towel, room: utility_room
# obj: toy_airplane, room: bathroom
# obj: toy_airplane, room: closet
# obj: toy_airplane, room: dining_room
# obj: toy_airplane, room: exercise_room
# obj: toy_airplane, room: garage
# obj: toy_airplane, room: television_room
# obj: toy_airplane, room: utility_room
# obj: toy_animal, room: childs_room
# obj: toy_animal, room: closet
# obj: toy_animal, room: corridor
# obj: toy_animal, room: dining_room
# obj: toy_animal, room: exercise_room
# obj: toy_animal, room: garage
# obj: toy_animal, room: home_office
# obj: toy_animal, room: kitchen
# obj: toy_animal, room: living_room
# obj: toy_animal, room: lobby
# obj: toy_animal, room: pantry_room
# obj: toy_animal, room: playroom
# obj: toy_animal, room: television_room
# obj: toy_animal, room: utility_room
# obj: toy_basketball, room: bathroom
# obj: toy_basketball, room: bedroom
# obj: toy_basketball, room: childs_room
# obj: toy_basketball, room: closet
# obj: toy_basketball, room: corridor
# obj: toy_basketball, room: dining_room
# obj: toy_basketball, room: exercise_room
# obj: toy_basketball, room: garage
# obj: toy_basketball, room: home_office
# obj: toy_basketball, room: kitchen
# obj: toy_basketball, room: living_room
# obj: toy_basketball, room: lobby
# obj: toy_basketball, room: pantry_room
# obj: toy_basketball, room: playroom
# obj: toy_basketball, room: storage_room
# obj: toy_basketball, room: television_room
# obj: toy_basketball, room: utility_room
# obj: toy_bowling_set, room: bathroom
# obj: toy_bowling_set, room: bedroom
# obj: toy_bowling_set, room: childs_room
# obj: toy_bowling_set, room: closet
# obj: toy_bowling_set, room: corridor
# obj: toy_bowling_set, room: dining_room
# obj: toy_bowling_set, room: exercise_room
# obj: toy_bowling_set, room: garage
# obj: toy_bowling_set, room: home_office
# obj: toy_bowling_set, room: kitchen
# obj: toy_bowling_set, room: living_room
# obj: toy_bowling_set, room: lobby
# obj: toy_bowling_set, room: pantry_room
# obj: toy_bowling_set, room: playroom
# obj: toy_bowling_set, room: storage_room
# obj: toy_bowling_set, room: television_room
# obj: toy_bowling_set, room: utility_room
# obj: toy_construction_set, room: bathroom
# obj: toy_construction_set, room: bedroom
# obj: toy_construction_set, room: childs_room
# obj: toy_construction_set, room: closet
# obj: toy_construction_set, room: corridor
# obj: toy_construction_set, room: dining_room
# obj: toy_construction_set, room: exercise_room
# obj: toy_construction_set, room: garage
# obj: toy_construction_set, room: home_office
# obj: toy_construction_set, room: kitchen
# obj: toy_construction_set, room: living_room
# obj: toy_construction_set, room: lobby
# obj: toy_construction_set, room: pantry_room
# obj: toy_construction_set, room: playroom
# obj: toy_construction_set, room: storage_room
# obj: toy_construction_set, room: television_room
# obj: toy_construction_set, room: utility_room
# obj: toy_fishing, room: bathroom
# obj: toy_fishing, room: bedroom
# obj: toy_fishing, room: childs_room
# obj: toy_fishing, room: closet
# obj: toy_fishing, room: corridor
# obj: toy_fishing, room: dining_room
# obj: toy_fishing, room: exercise_room
# obj: toy_fishing, room: garage
# obj: toy_fishing, room: home_office
# obj: toy_fishing, room: kitchen
# obj: toy_fishing, room: living_room
# obj: toy_fishing, room: lobby
# obj: toy_fishing, room: pantry_room
# obj: toy_fishing, room: playroom
# obj: toy_fishing, room: storage_room
# obj: toy_fishing, room: television_room
# obj: toy_fishing, room: utility_room
# obj: toy_food, room: bathroom
# obj: toy_food, room: bedroom
# obj: toy_food, room: childs_room
# obj: toy_food, room: closet
# obj: toy_food, room: corridor
# obj: toy_food, room: dining_room
# obj: toy_food, room: exercise_room
# obj: toy_food, room: garage
# obj: toy_food, room: kitchen
# obj: toy_food, room: living_room
# obj: toy_food, room: lobby
# obj: toy_food, room: pantry_room
# obj: toy_food, room: playroom
# obj: toy_food, room: storage_room
# obj: toy_food, room: television_room
# obj: toy_food, room: utility_room
# obj: toy_furniture_set, room: bathroom
# obj: toy_furniture_set, room: bedroom
# obj: toy_furniture_set, room: childs_room
# obj: toy_furniture_set, room: closet
# obj: toy_furniture_set, room: corridor
# obj: toy_furniture_set, room: dining_room
# obj: toy_furniture_set, room: exercise_room
# obj: toy_furniture_set, room: garage
# obj: toy_furniture_set, room: home_office
# obj: toy_furniture_set, room: kitchen
# obj: toy_furniture_set, room: living_room
# obj: toy_furniture_set, room: lobby
# obj: toy_furniture_set, room: playroom
# obj: toy_furniture_set, room: storage_room
# obj: toy_furniture_set, room: television_room
# obj: toy_furniture_set, room: utility_room
# obj: toy_instrument, room: bathroom
# obj: toy_instrument, room: bedroom
# obj: toy_instrument, room: childs_room
# obj: toy_instrument, room: closet
# obj: toy_instrument, room: corridor
# obj: toy_instrument, room: dining_room
# obj: toy_instrument, room: exercise_room
# obj: toy_instrument, room: garage
# obj: toy_instrument, room: home_office
# obj: toy_instrument, room: kitchen
# obj: toy_instrument, room: living_room
# obj: toy_instrument, room: lobby
# obj: toy_instrument, room: pantry_room
# obj: toy_instrument, room: playroom
# obj: toy_instrument, room: storage_room
# obj: toy_instrument, room: television_room
# obj: toy_instrument, room: utility_room
# obj: toy_kitchen_set, room: bathroom
# obj: toy_kitchen_set, room: bedroom
# obj: toy_kitchen_set, room: childs_room
# obj: toy_kitchen_set, room: closet
# obj: toy_kitchen_set, room: corridor
# obj: toy_kitchen_set, room: dining_room
# obj: toy_kitchen_set, room: exercise_room
# obj: toy_kitchen_set, room: garage
# obj: toy_kitchen_set, room: home_office
# obj: toy_kitchen_set, room: kitchen
# obj: toy_kitchen_set, room: living_room
# obj: toy_kitchen_set, room: lobby
# obj: toy_kitchen_set, room: pantry_room
# obj: toy_kitchen_set, room: playroom
# obj: toy_kitchen_set, room: storage_room
# obj: toy_kitchen_set, room: television_room
# obj: toy_tool_kit, room: bathroom
# obj: toy_tool_kit, room: bedroom
# obj: toy_tool_kit, room: childs_room
# obj: toy_tool_kit, room: closet
# obj: toy_tool_kit, room: corridor
# obj: toy_tool_kit, room: dining_room
# obj: toy_tool_kit, room: exercise_room
# obj: toy_tool_kit, room: garage
# obj: toy_tool_kit, room: home_office
# obj: toy_tool_kit, room: kitchen
# obj: toy_tool_kit, room: living_room
# obj: toy_tool_kit, room: lobby
# obj: toy_tool_kit, room: playroom
# obj: toy_tool_kit, room: storage_room
# obj: toy_tool_kit, room: television_room
# obj: toy_vehicle, room: bathroom
# obj: toy_vehicle, room: bedroom
# obj: toy_vehicle, room: childs_room
# obj: toy_vehicle, room: closet
# obj: toy_vehicle, room: corridor
# obj: toy_vehicle, room: dining_room
# obj: toy_vehicle, room: exercise_room
# obj: toy_vehicle, room: garage
# obj: toy_vehicle, room: home_office
# obj: toy_vehicle, room: kitchen
# obj: toy_vehicle, room: lobby
# obj: toy_vehicle, room: pantry_room
# obj: toy_vehicle, room: playroom
# obj: tray, room: bathroom
# obj: tray, room: bedroom
# obj: tray, room: childs_room
# obj: tray, room: closet
# obj: tray, room: corridor
# obj: tray, room: dining_room
# obj: tray, room: exercise_room
# obj: tray, room: garage
# obj: tray, room: home_office
# obj: tray, room: living_room
# obj: tray, room: lobby
# obj: tray, room: playroom
# obj: tray, room: storage_room
# obj: tumbler, room: bathroom
# obj: tumbler, room: bedroom
# obj: tumbler, room: childs_room
# obj: tumbler, room: closet
# obj: tumbler, room: corridor
# obj: tumbler, room: dining_room
# obj: tumbler, room: exercise_room
# obj: tumbler, room: garage
# obj: tumbler, room: home_office
# obj: tumbler, room: kitchen
# obj: tumbler, room: living_room
# obj: tumbler, room: lobby
# obj: tumbler, room: pantry_room
# obj: tumbler, room: playroom
# obj: tumbler, room: storage_room
# obj: tumbler, room: television_room
# obj: tumbler, room: utility_room
# obj: umbrella, room: bedroom
# obj: umbrella, room: childs_room
# obj: umbrella, room: closet
# obj: umbrella, room: dining_room
# obj: umbrella, room: exercise_room
# obj: umbrella, room: garage
# obj: umbrella, room: home_office
# obj: umbrella, room: living_room
# obj: umbrella, room: lobby
# obj: umbrella, room: playroom
# obj: umbrella, room: storage_room
# obj: umbrella, room: television_room
# obj: umbrella, room: utility_room
# obj: usb_drive, room: bathroom
# obj: usb_drive, room: bedroom
# obj: usb_drive, room: childs_room
# obj: usb_drive, room: closet
# obj: usb_drive, room: corridor
# obj: usb_drive, room: dining_room
# obj: usb_drive, room: exercise_room
# obj: usb_drive, room: garage
# obj: usb_drive, room: home_office
# obj: usb_drive, room: kitchen
# obj: usb_drive, room: living_room
# obj: usb_drive, room: lobby
# obj: usb_drive, room: pantry_room
# obj: usb_drive, room: playroom
# obj: usb_drive, room: storage_room
# obj: usb_drive, room: television_room
# obj: usb_drive, room: utility_room
# obj: utensil_holder, room: bathroom
# obj: utensil_holder, room: bedroom
# obj: utensil_holder, room: childs_room
# obj: utensil_holder, room: closet
# obj: utensil_holder, room: corridor
# obj: utensil_holder, room: dining_room
# obj: utensil_holder, room: exercise_room
# obj: utensil_holder, room: garage
# obj: utensil_holder, room: home_office
# obj: utensil_holder, room: kitchen
# obj: utensil_holder, room: living_room
# obj: utensil_holder, room: lobby
# obj: utensil_holder, room: pantry_room
# obj: utensil_holder, room: playroom
# obj: utensil_holder, room: storage_room
# obj: utensil_holder, room: television_room
# obj: vase, room: closet
# obj: vase, room: corridor
# obj: vase, room: exercise_room
# obj: vase, room: garage
# obj: vase, room: lobby
# obj: vase, room: pantry_room
# obj: vase, room: television_room
# obj: video_game, room: bathroom
# obj: video_game, room: bedroom
# obj: video_game, room: childs_room
# obj: video_game, room: closet
# obj: video_game, room: dining_room
# obj: video_game, room: exercise_room
# obj: video_game, room: garage
# obj: video_game, room: home_office
# obj: video_game, room: kitchen
# obj: video_game, room: living_room
# obj: video_game, room: lobby
# obj: video_game, room: pantry_room
# obj: video_game, room: storage_room
# obj: video_game, room: television_room
# obj: video_game, room: utility_room
# obj: vinyl_tape, room: bathroom
# obj: vinyl_tape, room: bedroom
# obj: vinyl_tape, room: closet
# obj: vinyl_tape, room: corridor
# obj: vinyl_tape, room: dining_room
# obj: vinyl_tape, room: exercise_room
# obj: vinyl_tape, room: garage
# obj: vinyl_tape, room: home_office
# obj: vinyl_tape, room: living_room
# obj: vinyl_tape, room: lobby
# obj: vinyl_tape, room: pantry_room
# obj: vinyl_tape, room: playroom
# obj: vinyl_tape, room: television_room
# obj: vinyl_tape, room: utility_room
# obj: virtual_reality_viewer, room: bathroom
# obj: virtual_reality_viewer, room: bedroom
# obj: virtual_reality_viewer, room: childs_room
# obj: virtual_reality_viewer, room: closet
# obj: virtual_reality_viewer, room: corridor
# obj: virtual_reality_viewer, room: dining_room
# obj: virtual_reality_viewer, room: exercise_room
# obj: virtual_reality_viewer, room: garage
# obj: virtual_reality_viewer, room: home_office
# obj: virtual_reality_viewer, room: kitchen
# obj: virtual_reality_viewer, room: living_room
# obj: virtual_reality_viewer, room: lobby
# obj: virtual_reality_viewer, room: pantry_room
# obj: virtual_reality_viewer, room: playroom
# obj: virtual_reality_viewer, room: storage_room
# obj: virtual_reality_viewer, room: television_room
# obj: virtual_reality_viewer, room: utility_room
# obj: washcloth, room: bathroom
# obj: washcloth, room: bedroom
# obj: washcloth, room: closet
# obj: washcloth, room: corridor
# obj: washcloth, room: dining_room
# obj: washcloth, room: exercise_room
# obj: washcloth, room: garage
# obj: washcloth, room: home_office
# obj: washcloth, room: living_room
# obj: washcloth, room: lobby
# obj: washcloth, room: pantry_room
# obj: washcloth, room: playroom
# obj: washcloth, room: storage_room
# obj: washcloth, room: television_room
# obj: washcloth, room: utility_room
# obj: waste_basket, room: bathroom
# obj: waste_basket, room: bedroom
# obj: waste_basket, room: childs_room
# obj: waste_basket, room: closet
# obj: waste_basket, room: corridor
# obj: waste_basket, room: dining_room
# obj: waste_basket, room: exercise_room
# obj: waste_basket, room: garage
# obj: waste_basket, room: home_office
# obj: waste_basket, room: kitchen
# obj: waste_basket, room: living_room
# obj: waste_basket, room: lobby
# obj: waste_basket, room: pantry_room
# obj: waste_basket, room: storage_room
# obj: waste_basket, room: television_room
# obj: waste_basket, room: utility_room
# obj: water_bottle, room: bathroom
# obj: water_bottle, room: bedroom
# obj: water_bottle, room: childs_room
# obj: water_bottle, room: corridor
# obj: water_bottle, room: dining_room
# obj: water_bottle, room: exercise_room
# obj: water_bottle, room: garage
# obj: water_bottle, room: home_office
# obj: water_bottle, room: living_room
# obj: water_bottle, room: lobby
# obj: water_bottle, room: pantry_room
# obj: water_bottle, room: television_room
# obj: water_bottle, room: utility_room
# obj: weight_loss_guide, room: bathroom
# obj: weight_loss_guide, room: bedroom
# obj: weight_loss_guide, room: childs_room
# obj: weight_loss_guide, room: closet
# obj: weight_loss_guide, room: corridor
# obj: weight_loss_guide, room: dining_room
# obj: weight_loss_guide, room: exercise_room
# obj: weight_loss_guide, room: garage
# obj: weight_loss_guide, room: home_office
# obj: weight_loss_guide, room: kitchen
# obj: weight_loss_guide, room: living_room
# obj: weight_loss_guide, room: lobby
# obj: weight_loss_guide, room: pantry_room
# obj: weight_loss_guide, room: playroom
# obj: weight_loss_guide, room: storage_room
# obj: weight_loss_guide, room: television_room
# obj: weight_loss_guide, room: utility_room
# obj: whale_whistle, room: bathroom
# obj: whale_whistle, room: bedroom
# obj: whale_whistle, room: childs_room
# obj: whale_whistle, room: closet
# obj: whale_whistle, room: corridor
# obj: whale_whistle, room: dining_room
# obj: whale_whistle, room: exercise_room
# obj: whale_whistle, room: garage
# obj: whale_whistle, room: home_office
# obj: whale_whistle, room: kitchen
# obj: whale_whistle, room: living_room
# obj: whale_whistle, room: lobby
# obj: whale_whistle, room: pantry_room
# obj: whale_whistle, room: storage_room
# obj: whale_whistle, room: television_room
# obj: wipe_warmer, room: bathroom
# obj: wipe_warmer, room: childs_room
# obj: wipe_warmer, room: closet
# obj: wipe_warmer, room: corridor
# obj: wipe_warmer, room: dining_room
# obj: wipe_warmer, room: exercise_room
# obj: wipe_warmer, room: garage
# obj: wipe_warmer, room: home_office
# obj: wipe_warmer, room: kitchen
# obj: wipe_warmer, room: living_room
# obj: wipe_warmer, room: lobby
# obj: wipe_warmer, room: pantry_room
# obj: wipe_warmer, room: playroom
# obj: wipe_warmer, room: storage_room
# obj: wipe_warmer, room: television_room
# obj: wipe_warmer, room: utility_room
# obj: wireless_accessory, room: bathroom
# obj: wireless_accessory, room: bedroom
# obj: wireless_accessory, room: closet
# obj: wireless_accessory, room: exercise_room
# obj: wireless_accessory, room: garage
# obj: wireless_accessory, room: home_office
# obj: wireless_accessory, room: kitchen
# obj: wireless_accessory, room: living_room
# obj: wireless_accessory, room: pantry_room
# obj: wireless_accessory, room: storage_room
# obj: xylitol_sweetener, room: bathroom
# obj: xylitol_sweetener, room: bedroom
# obj: xylitol_sweetener, room: childs_room
# obj: xylitol_sweetener, room: closet
# obj: xylitol_sweetener, room: corridor
# obj: xylitol_sweetener, room: dining_room
# obj: xylitol_sweetener, room: exercise_room
# obj: xylitol_sweetener, room: garage
# obj: xylitol_sweetener, room: home_office
# obj: xylitol_sweetener, room: kitchen
# obj: xylitol_sweetener, room: living_room
# obj: xylitol_sweetener, room: lobby
# obj: xylitol_sweetener, room: playroom
# obj: xylitol_sweetener, room: storage_room
# obj: xylitol_sweetener, room: television_room
# obj: xylitol_sweetener, room: utility_room
# done

# %% [markdown]
# ## Calculate annotater agreement scores (Fleiss' Kappa)

# %%
def fleiss_kappa(subject_label_mat):

    assert isinstance(subject_label_mat, np.ndarray)

    rowwise_sum = np.sum(subject_label_mat, axis=1)
    nonzero_rows = np.where(rowwise_sum > 0)[0]

    # print('non0 rows: ', nonzero_rows) #DEBUG

    working_matrix = subject_label_mat[nonzero_rows, :]
    rowwise_sum_working = np.sum(working_matrix, axis=1) # number of ratings per subject

    #DEBUG
    # print('number of receptacles: ', len(working_matrix), ' | num of ratings for this obj: ', np.sum(working_matrix))
    # TODO: assert len(working_matrix)*10 == np.sum(working_matrix) # 10 annotators per  

    # proportion of assignments belonging to jth category/column
    p_j_array = np.sum(working_matrix, axis=0)/np.sum(working_matrix)
    assert len(p_j_array) == working_matrix.shape[1]

    # agreement score for category i w.r.t. total number of annotator pairs
    P_i_array = np.sum(working_matrix**2 - working_matrix, axis=1)/(rowwise_sum_working**2 - rowwise_sum_working)
    assert len(P_i_array) == working_matrix.shape[0]

    P_i_mean = np.sum(P_i_array)/len(P_i_array)

    P_e_mean = np.sum(p_j_array**2)

    return 1.0*(P_i_mean-P_e_mean)/(1-P_e_mean+1e-3)

# %%
object_agreement_scores = dict({})

for object_idx in range(268):
    for room_idx in range(17):
        filtered_values = np.where((data['object_idx']==object_idx)&(data['room_idx']==room_idx))

        receptacle2labels = np.zeros((128, 2)) # receptacle2labels[rcpt] = correct/incorrect(misplaced, implausible)

        for i, d in data.loc[filtered_values].iterrows():
            for rcpt in d['correct']:
                receptacle2labels[rcpt, 0] += 1

            for rcpt in d['misplaced']:
                receptacle2labels[rcpt, 1] += 1

            for rcpt in d['implausible']:
                receptacle2labels[rcpt, 1] += 1

        object_agreement_scores['{}/{}'.format(objects[object_idx], rooms[room_idx])] = fleiss_kappa(receptacle2labels)

# save all objects with agreement scores less than 0.2
with open('housekeep_less_than_fair_agreement.txt', 'w') as fw:
    for k, v in object_agreement_scores.items():
        if v < 0.2:
            fw.write(f'{k},{v}\n')

# %% [markdown]
# ## Misc: Clustering object-receptacle pairs based on distance threshold

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
import seaborn as sns

THRESHOLD = 0.3

clustering_pandas_df = pd.DataFrame([], 
    columns=['objectid', 'roomid', 'num_clusters', 'cluster_asgns'])

for object_idx in range(268):

  filtered_values = np.where(data['object_idx'] == object_idx)
  annotators = []
  datapoints = []

  # lists to vector
  for i, d in data.loc[filtered_values].iterrows():

    vec = np.concatenate([receptacle_labels2vec(d['correct']), 
                            receptacle_labels2vec(d['misplaced']),
                            receptacle_labels2vec(d['implausible'])])

    annotators.append(d['annotator_idx'])
    datapoints.append(vec[np.newaxis, :])

  # array of datapoints
  datapoints_array = np.concatenate(datapoints, axis=0)

  # pairwise distance matrix
  pairwise_dist_mat = np.zeros((len(datapoints_array), len(datapoints_array)))
  for i1, d1 in enumerate(datapoints_array):
    for i2, d2 in enumerate(datapoints_array):
      pairwise_dist_mat[i1, i2] = distance_metric(d1, d2)

  # clusters
  clusters = AgglomerativeClustering(n_clusters=None, affinity="precomputed", linkage="single", distance_threshold=THRESHOLD).fit_predict(pairwise_dist_mat)
  num_clusters = 1 + max(clusters)

  clustering_pandas_df = pd.concat([clustering_pandas_df, pd.DataFrame(dict({'objectid':[object_idx],
                                                                              'num_clusters': [num_clusters],
                                                                              'cluster_asgns': (len(clusters)*'{}-').format(*clusters)
                                                                                }))
                                    ], ignore_index=True)

# %%
if THRESHOLD == 0.5:
    clustering_pandas_df.to_csv('./dataframe_distthresh-5en1.csv', encoding = 'utf-8-sig')
elif THRESHOLD == 0.7:
    clustering_pandas_df.to_csv('./dataframe_distthresh-7en1.csv', encoding = 'utf-8-sig')
elif THRESHOLD == 0.3:
    clustering_pandas_df.to_csv('./dataframe_distthresh-3en1.csv', encoding = 'utf-8-sig')

# %%
import matplotlib.pyplot as plt

THRESHOLD = 0.3
if THRESHOLD == 0.5:
    clustering_pandas_df = pd.read_csv('./dataframe_distthresh-5en1.csv')
elif THRESHOLD == 0.7:
    clustering_pandas_df = pd.read_csv('./dataframe_distthresh-7en1.csv')
elif THRESHOLD == 0.3:
    clustering_pandas_df = pd.read_csv('./dataframe_distthresh-3en1.csv')

tuples_to_plot = pd.DataFrame([], columns=['obj_room', 'num_clusters'])
for _, row in clustering_pandas_df.iterrows():
  newdf = pd.DataFrame(
      dict({'obj_room':['o{}r{}'.format(row['objectid'], row['roomid'])],
            'num_clusters': [row['num_clusters']]
            })
      )
  tuples_to_plot = pd.concat([tuples_to_plot, newdf], ignore_index=True)

plt.figure(figsize=(12, 8))
sns.histplot(data=tuples_to_plot, x='num_clusters', discrete=True)
plt.xticks(range(11))
tuples_to_plot.head()
